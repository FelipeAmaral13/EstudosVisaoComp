# %%
from __future__ import print_function

import pyzbar.pyzbar as pyzbar
import numpy as np
import cv2
import time

#webcam:  
cap = cv2.VideoCapture(0)

cap.set(3,640)
cap.set(4,480)

time.sleep(2)

def decode(im) : 
    # Prcurar QRCodes ou Barras
    decodedObjects = pyzbar.decode(im)
    # Print resultadoss
    for obj in decodedObjects:
        print('Type : ', obj.type)
        print('Data : ', obj.data,'\n')     
    return decodedObjects


font = cv2.FONT_HERSHEY_SIMPLEX

while(cap.isOpened()):
    ret, frame = cap.read()
    im = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
         
    decodedObjects = decode(im)

    for decodedObject in decodedObjects: 
        points = decodedObject.polygon
     
        # Se os pontos não formarem um quad, procure convex hull
        if len(points) > 4 :
            hull = cv2.convexHull(np.array([point for point in points], dtype=np.float32))
            hull = list(map(tuple, np.squeeze(hull)))
        else : 
            hull = points;
         
        #Numero de pontos do convex hull
        n = len(hull)     
        # Desenhar o convext hull
        for j in range(0,n):
            cv2.line(frame, hull[j], hull[ (j+1) % n], (255,0,0), 3)

        x = decodedObject.rect.left
        y = decodedObject.rect.top

        print(x, y)

        print('Type : ', decodedObject.type)
        print('Data : ', decodedObject.data,'\n')

        barCode = str(decodedObject.data)
        cv2.putText(frame, barCode, (x, y), font, 1, (0,255,255), 2, cv2.LINE_AA)
               
    cv2.imshow('frame',frame)
    key = cv2.waitKey(1)
    if key & 0xFF == ord('q'):
        break
    elif key & 0xFF == ord('s'): #Se apertar 's', salvar o qrcode
        cv2.imwrite('Capture.png', frame)     

cap.release()
cv2.destroyAllWindows()
# Out:
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 42 136
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 44 141
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 116 124
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 122 115
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 121 109
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 113 103
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 104 98
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 95 99
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 78 99
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 69 99
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 64 101
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 59 102
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 60 101
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 63 103
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 67 105
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 68 101
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 68 97
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 75 93
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 79 90
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 87 89
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 93 88
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 101 92
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 109 99
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 112 103
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 118 113
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 124 122
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 134 136
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 139 138
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 152 142
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 164 145
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 174 145
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 182 142
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 189 139
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 196 138
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 200 135
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 203 132
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 207 133
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 209 133
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 204 134
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 196 134
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 190 133
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 184 132
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 177 133
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 168 136
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 158 140
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 148 143
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 136 145
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 125 147
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 111 149
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 100 150
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 89 151
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 76 151
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 67 154
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 56 155
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 51 158
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 41 163
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 37 167
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 32 166
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 29 166
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 30 168
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 33 172
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 35 172
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 41 176
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 49 181
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 59 194
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 66 206
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 45 223
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 45 218
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 46 213
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 47 209
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 50 203
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 52 198
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 54 193
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 54 190
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 56 189
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 60 187
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 63 185
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 69 181
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 71 181
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 73 179
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 76 176
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 78 173
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 80 173
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 82 172
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 81 174
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 80 177
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 81 181
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 83 183
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 84 184
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 86 186
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 87 188
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 91 185
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 98 180
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 100 180
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 103 177
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 151 272
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 157 272
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 100 156
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 94 155
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 88 153
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 83 152
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 81 150
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 79 150
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 79 150
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 79 149
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# 80 149
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
# Type :  QRCODE
# Data :  b'http://redeglobo.globo.com/globociencia'
#
#